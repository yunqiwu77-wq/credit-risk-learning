# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Environment ready.")
# Out:
# Environment ready.

# %%
loan_data=pd.DataFrame({"Client":["Alice","Bob","Charlie","David","Emma"], "Age":[25,42,37,29,51],"Income":[35000,72000,58000,41000,90000],"Loan":[12000,25000,18000,8000,40000],"Default":[0,0,1,0,1]})
loan_data
# Out:
#     Client  Age  Income   Loan  Default
# 0    Alice   25   35000  12000        0
# 1      Bob   42   72000  25000        0
# 2  Charlie   37   58000  18000        1
# 3    David   29   41000   8000        0
# 4     Emma   51   90000  40000        1

# %%
loan_data.head()
# Out:
#     Client  Age  Income   Loan  Default
# 0    Alice   25   35000  12000        0
# 1      Bob   42   72000  25000        0
# 2  Charlie   37   58000  18000        1
# 3    David   29   41000   8000        0
# 4     Emma   51   90000  40000        1

# %%
loan_data.info
# Out:
# <bound method DataFrame.info of     Client  Age  Income   Loan  Default
# 0    Alice   25   35000  12000        0
# 1      Bob   42   72000  25000        0
# 2  Charlie   37   58000  18000        1
# 3    David   29   41000   8000        0
# 4     Emma   51   90000  40000        1>

# %%
loan_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Client   5 non-null      str
#  1   Age      5 non-null      int64
#  2   Income   5 non-null      int64
#  3   Loan     5 non-null      int64
#  4   Default  5 non-null      int64
# dtypes: int64(4), str(1)
# memory usage: 332.0 bytes

# %%
loan_data.describe()
# Out:
#              Age        Income          Loan   Default
# count   5.000000      5.000000      5.000000  5.000000
# mean   36.800000  59200.000000  20600.000000  0.400000
# std    10.353743  22532.199183  12601.587202  0.547723
# min    25.000000  35000.000000   8000.000000  0.000000
# 25%    29.000000  41000.000000  12000.000000  0.000000
# 50%    37.000000  58000.000000  18000.000000  0.000000
# 75%    42.000000  72000.000000  25000.000000  1.000000
# max    51.000000  90000.000000  40000.000000  1.000000

# %%
default_rate = loan_data["Default"].mean()

print(f"Default Rate = {default_rate:.2%}")
# Out:
# Default Rate = 40.00%

# %%
print (f"Default Rate="default_rate"")
# Out:
#   Cell In[16], line 1
#     print (f"Default Rate="default_rate"")
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
client = "Alice"
loan= 25000
income=5000

print (f"Client {client} has a loan of €{loan:,.0f} and an income of €{income:,.0f}")
# Out:
# Client Alice has a loan of €25,000 and an income of €5,000

# %%
print("Average loan:",loan_data["Loan"].mean() )
# Out:
# Average loan: 20600.0

# %%
print ("Maximum Loan:", loan_data["Loan"].max())
# Out:
# Maximum Loan: 40000

# %%
print("Minimum Loan:",loan_data["Loan"].min())
# Out:
# Minimum Loan: 8000

# %%
plt.figure(figsize=(8,4))
plt.bar(loan_data["Client"],loan_data["Loan"])
plt.title("Loan Amount by Client")
plt.xlabel("Client")
plt.ylabel("Loan(€)")
plt.show()

# %%
loan_data[loan_data["Default"]==1]
# Out:
#     Client  Age  Income   Loan  Default
# 2  Charlie   37   58000  18000        1
# 4     Emma   51   90000  40000        1

# %%
loan_data[loan_data["Default"]==1]
# Out:
#     Client  Age  Income   Loan  Default
# 2  Charlie   37   58000  18000        1
# 4     Emma   51   90000  40000        1

# %%
print ("Average Income:", loan_data["Income"].mean())
# Out:
# Average Income: 59200.0

# %%
Income_max=loan_data["Income"].max()
print(loan_data[loan_data["Income"]==Income_max]["Client"])
# Out:
# 4    Emma
# Name: Client, dtype: str

# %%
loan_data["Debt-to-Income"] = loan_data["Loan"] / loan_data["Income"]

# %%
print (loan_data)
# Out:
#     Client  Age  Income   Loan  Default  Debt-to-Income
# 0    Alice   25   35000  12000        0        0.342857
# 1      Bob   42   72000  25000        0        0.347222
# 2  Charlie   37   58000  18000        1        0.310345
# 3    David   29   41000   8000        0        0.195122
# 4     Emma   51   90000  40000        1        0.444444

# %%
##
The portfolio contains 5 clients. The default rate is 40%. The average loan amount is €20,600.
