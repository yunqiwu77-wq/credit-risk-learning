# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

loan_data = pd.DataFrame({
    "Client": ["Alice","Bob","Charlie","David","Emma","Frank","Grace","Helen"],
    "Age":[25,42,37,29,51,45,33,27],
    "Income":[35000,72000,58000,41000,90000,68000,55000,39000],
    "Loan":[12000,25000,18000,8000,40000,28000,15000,10000],
    "Default":[0,0,1,0,1,0,1,0]
})

loan_data
# Out:
#     Client  Age  Income   Loan  Default
# 0    Alice   25   35000  12000        0
# 1      Bob   42   72000  25000        0
# 2  Charlie   37   58000  18000        1
# 3    David   29   41000   8000        0
# 4     Emma   51   90000  40000        1
# 5    Frank   45   68000  28000        0
# 6    Grace   33   55000  15000        1
# 7    Helen   27   39000  10000        0

# %%
loan_data.shape
# Out:
# (8, 5)

# %%
loan_data.columns
# Out:
# Index(['Client', 'Age', 'Income', 'Loan', 'Default'], dtype='str')
