# %%
import sys

print(sys.version)
print(sys.executable)

# %%
py -3.12 -m pip install ipykernel
py -3.12 -m ipykernel install --user --name python312 --display-name "Python 3.12"

# %%
import sys
print(sys.version)
print(sys.executable)

# %%
import sys

print(sys.executable)

# %%
import sys

# !{sys.executable} -m pip install numpy scipy pandas matplotlib scikit-learn statsmodels xgboost lightgbm

# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import statsmodels
import xgboost
import lightgbm

print("✅ All packages imported successfully!")

# %%
print("hello")
# Out:
# hello

# %%
import sys
print(sys.executable)

import numpy as np
import pandas as pd

print(np.__version__)
print(pd.__version__)
# Out:
# C:\Users\WU\miniconda3\envs\py312\python.exe
# 2.5.0
# 3.0.4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Environment ready.")
# Out:
# Environment ready.
